# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
league_2017 = 'csv/csv_combo_stats/combo_stats_2017_From-season_end.csv'
league_2018 = 'csv/cumulative_player_stats-20172018.csv'

read_2017 = pd.read_csv(league_2018, dtype = object)

# %%
read_2017.head()
# Out:
#   Date/Time of Update: 2018-04-16 11:12:29 AM Player ID    LastName  \
# 0                                         NaN      4419  Abdelkader
# 1                                         NaN      9554       Aberg
# 2                                         NaN      5927     Acciari
# 3                                         NaN      5353    Agostino
# 4                                         NaN      5630         Aho
#
#    FirstName Jersey Num Position Height Weight Birth Date Age  ...  Rookie  \
# 0     Justin          8       LW   6'2"    214  2/25/1987  31  ...       N
# 1     Pontus         46       LW  5'11"    196  9/22/1993  24  ...       N
# 2       Noel         55        C  5'10"    208  12/1/1991  26  ...       N
# 3      Kenny         18       LW   6'0"    202  4/30/1992  25  ...       N
# 4  Sebastian         20       RW  5'11"    172  7/26/1997  20  ...       N
#
#   Team ID Team Abbr. Team City   Team Name GamesPlayed Goals Assists Points  \
# ...
