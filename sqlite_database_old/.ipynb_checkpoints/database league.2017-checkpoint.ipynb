# %%
import os

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
league_2017 = 'csv/cumulative_player_stats-20162017.csv'
league_2018 = 'csv/cumulative_player_stats-20172018.csv'

read_2017 = pd.read_csv(league_2017, dtype = object)
read_2018 = pd.read_csv(league_2018, dtype = object)

# %%
read_2017.head()
# Out:
#   Player_ID    LastName FirstName Jersey_Num Position Height Weight  \
# 0      5263      Abbott   Spencer         24       LW   5'9"    170
# 1      4419  Abdelkader    Justin          8       LW   6'2"    214
# 2      9554       Aberg    Pontus         46       LW  5'11"    196
# 3      5927     Acciari      Noel         55        C  5'10"    208
# 4      5353    Agostino     Kenny         73       LW   6'0"    202
#
#   Birth_Date Age      Birth_City  ...  Rookie Team_ID Team_Abbr  Team_City  \
# 0  4/30/1988  29    Hamilton, ON  ...       Y      20       CHI    Chicago
# 1  2/25/1987  31    Muskegon, MI  ...       N      16       DET    Detroit
# 2  9/22/1993  24       Stockholm  ...       Y      18       NSH  Nashville
# 3  12/1/1991  26    Johnston, RI  ...       N      11       BOS     Boston
# 4  4/30/1992  25  Morristown, NJ  ...       N      17       STL  St. Louis
#
#     Team_Name GamesPlayed Goals Assists Points Shots
# 0  Blackhawks           1     0       0      0     1
# 1   Red Wings          64     7      14     21   104
# 2   Predators          15     1       1      2    12
# 3      Bruins          29     2       3      5    24
# 4       Blues           7     1       2      3    17
#
# [5 rows x 21 columns]

# %%
read_2018.head()
# Out:
#   Player_ID    LastName  FirstName Jersey_Num Position Height Weight  \
# 0      4419  Abdelkader     Justin          8       LW   6'2"    214
# 1      9554       Aberg     Pontus         46       LW  5'11"    196
# 2      5927     Acciari       Noel         55        C  5'10"    208
# 3      5353    Agostino      Kenny         18       LW   6'0"    202
# 4      5630         Aho  Sebastian         20       RW  5'11"    172
#
#   Birth_Date Age      Birth_City  ...  Rookie Team_ID Team_Abbr Team_City  \
# 0  2/25/1987  31    Muskegon, MI  ...       N      16       DET   Detroit
# 1  9/22/1993  24       Stockholm  ...       N      24       EDM  Edmonton
# 2  12/1/1991  26    Johnston, RI  ...       N      11       BOS    Boston
# 3  4/30/1992  25  Morristown, NJ  ...       N      11       BOS    Boston
# 4  7/26/1997  20           Rauma  ...       N       3       CAR  Carolina
#
#     Team_Name GamesPlayed Goals Assists Points Shots
# 0   Red Wings          75    13      22     35   110
# 1      Oilers          53     4      12     16    70
# 2      Bruins          60    10       1     11    66
# 3      Bruins           5     0       1      1    11
# 4  Hurricanes          78    29      36     65   200
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Creating Sqlite Database

# %%
#Python SQL toolkite and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Column, String, Integer
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, MetaData, inspect, func

# %%
Declare_Base = declarative_base()

class NHL_2017(Declare_Base):
    __tablename__ = 'stat_2017'
    
    id = Column(Integer, primary_key = True) 
    Player_ID = Column(Integer) 
    LastName = Column(String)
    FirstName = Column(String)
    Jersey_Num = Column(Integer)
    Position = Column(String)
    Height = Column(String)
    Weight = Column(Integer)
    Birth_Date = Column(String)
    Age = Column(Integer)
    Birth_City = Column(String)
    Birth_Country = Column(String)
    Rookie = Column(String)
    Team_ID = Column(Integer)
    Team_Abbr = Column(String)
    Team_City = Column(String)
    Team_Name = Column(String)
    GamesPlayed = Column(Integer)
    Goals = Column(Integer)
    Assists = Column(Integer)
    Points = Column(Integer)
    Shots = Column(Integer)
    
    def __repr__(self):
        return f'id={self.id},name={self.name}'

# %%
engine = create_engine('sqlite:///league_2017.sqlite')
conn = engine.connect()

# %%
Declare_Base.metadata.create_all(engine)

# %%
nhl_2017 = read_2017.to_dict(orient = 'records')

# %%
print(nhl_2017)
# Out:
# [{'Player_ID': '5263', 'LastName': 'Abbott', 'FirstName': 'Spencer', 'Jersey_Num': '24', 'Position': 'LW', 'Height': '5\'9"', 'Weight': '170', 'Birth_Date': '4/30/1988', 'Age': '29', 'Birth_City': 'Hamilton, ON', 'Birth_Country': 'Canada', 'Rookie': 'Y', 'Team_ID': '20', 'Team_Abbr': 'CHI', 'Team_City': 'Chicago', 'Team_Name': 'Blackhawks', 'GamesPlayed': '1', 'Goals': '0', 'Assists': '0', 'Points': '0', 'Shots': '1'}, {'Player_ID': '4419', 'LastName': 'Abdelkader', 'FirstName': 'Justin', 'Jersey_Num': '8', 'Position': 'LW', 'Height': '6\'2"', 'Weight': '214', 'Birth_Date': '2/25/1987', 'Age': '31', 'Birth_City': 'Muskegon, MI', 'Birth_Country': 'USA', 'Rookie': 'N', 'Team_ID': '16', 'Team_Abbr': 'DET', 'Team_City': 'Detroit', 'Team_Name': 'Red Wings', 'GamesPlayed': '64', 'Goals': '7', 'Assists': '14', 'Points': '21', 'Shots': '104'}, {'Player_ID': '9554', 'LastName': 'Aberg', 'FirstName': 'Pontus', 'Jersey_Num': '46', 'Position': 'LW', 'Height': '5\'11"', 'Weight': '196', 'Birth_Date': '9/22/1993', 'Age': '24', 'Birth_City': 'Stockholm', 'Birth_Country': 'Sweden', 'Rookie': 'Y', 'Team_ID': '18', 'Team_Abbr': 'NSH', 'Team_City': 'Nashville', 'Team_Name': 'Predators', 'GamesPlayed': '15', 'Goals': '1', 'Assists': '1', 'Points': '2', 'Shots': '12'}, {'Player_ID': '5927', 'LastName': 'Acciari', 'FirstName': 'Noel', 'Jersey_Num': '55', 'Position': 'C', 'Height': '5\'10"', 'Weight': '208', 'Birth_Date': '12/1/1991', 'Age': '26', 'Birth_City': 'Johnston, RI', 'Birth_Country': 'USA', 'Rookie': 'N', 'Team_ID': '11', 'Team_Abbr': 'BOS', 'Team_City': 'Boston', 'Team_Name': 'Bruins', 'GamesPlayed': '29', 'Goals': '2', 'Assists': '3', 'Points': '5', 'Shots': '24'}, {'Player_ID': '5353', 'LastName': 'Agostino', 'FirstName': 'Kenny', 'Jersey_Num': '73', 'Position': 'LW', 'Height': '6\'0"', 'Weight': '202', 'Birth_Date': '4/30/1992', 'Age': '25', 'Birth_City': 'Morristown, NJ', 'Birth_Country': 'USA', 'Rookie': 'N', 'Team_ID': '17', 'Team_Abbr': 'STL', 'Team_City': 'St. Louis', 'Team_Name': 'Blues', 'GamesPlayed': '7', 'Goals': '1', 'Assists': '2', 'Points': '3', 'Shots': '17'}, {'Player_ID': '5630', 'LastName': 'Aho', 'FirstName': 'Sebastian', 'Jersey_Num': '20', 'Position': 'RW', 'Height': '5\'11"', 'Weight': '172', 'Birth_Date': '7/26/1997', 'Age': '20', 'Birth_City': 'Rauma', 'Birth_Country': 'Finland', 'Rookie': 'Y', 'Team_ID': '3', 'Team_Abbr': 'CAR', 'Team_City': 'Carolina', 'Team_Name': 'Hurricanes', 'GamesPlayed': '82', 'Goals': '24', 'Assists': '25', 'Points': '49', 'Shots': '214'}, {'Player_ID': '5107', 'LastName': 'Allen', 'FirstName': 'Jake', 'Jersey_Num': '34', 'Position': 'G', 'Height': '6\'2"', 'Weight': '203', 'Birth_Date': '8/7/1990', 'Age': '27', 'Birth_City': 'Fredericton, NB', 'Birth_Country': 'Canada', 'Rookie': 'N', 'Team_ID': '17', 'Team_Abbr': 'STL', 'Team_City': 'St. Louis', 'Team_Name': 'Blues', 'GamesPlayed': '61', 'Goals': '0', 'Assists': '1', 'Points': '1', 'Shots': nan}, {'Player_ID': '4554', 'LastName': 'Alzner', 'FirstName': 'Karl', 'Jersey_Num': '27', 'Position': 'D', 'Height': '6\'3"', 'Weight': '217', 'Birth_Date': '9/24/1988', 'Age': '29', 'Birth_City': 'Burnaby, BC', 'Birth_Country': 'Canada', 'Rookie': 'N', 'Team_ID': '5', 'Team_Abbr': 'WSH', 'Team_City': 'Washington', 'Team_Name': 'Capitals', 'GamesPlayed': '82', 'Goals': '3', 'Assists': '10', 'Points': '13', 'Shots': '80'}, {'Player_ID': '5109', 'LastName': 'Andersen', 'FirstName': 'Frederik', 'Jersey_Num': '31', 'Position': 'G', 'Height': '6\'4"', 'Weight': '230', 'Birth_Date': '9/30/1989', 'Age': '28', 'Birth_City': 'Herning', 'Birth_Country': 'Denmark', 'Rookie': 'N', 'Team_ID': '12', 'Team_Abbr': 'TOR', 'Team_City': 'Toronto', 'Team_Name': 'Maple Leafs', 'GamesPlayed': '66', 'Goals': '0', 'Assists': '1', 'Points': '1', 'Shots': nan}, {'Player_ID': '757', 'LastName': 'Anderson', 'FirstName': 'Craig', 'Jersey_Num': '41', 'Position': 'G', 'Height': '6\'2"', 'Weight': '187', 'Birth_Date': '5/21/1981', 'Age': '36', 'Birth_City': 'Park Ridge, IL', 'Bir ...

# %% [markdown]
# ### testing database

# %%
engine = create_engine('sqlite:///league_2017.sqlite', echo = False)

# %%
engine.execute('SELECT * FROM stat_2017 LIMIT 5').fetchall()
# Out:
# []

# %%
inspector = inspect(engine_test)
inspector.get_table_names()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-d8f065805249> in <module>()
# ----> 1 inspector = inspect(engine_test)
#       2 inspector.get_table_names()
#
# NameError: name 'engine_test' is not defined

# %%
columns = inspector.get_columns('stat_2017')
for column in columns:
    print(column['name'], column['type'])

# %% [markdown]
# ### Reflect and query

# %%
#Reflect Database into ORM class
Base = automap_base()
Base.prepare(engine, reflect = True)
STAT_2017 = Base.classes.stat_2017

# %%
session = Session(engine)

# %% [markdown]
# ### Analysis

# %%
session.query(STAT_2017.Shots).group_by(STAT_2017.Age).all()
# Out:
# []
